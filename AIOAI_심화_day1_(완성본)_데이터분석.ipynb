# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahnjihye/allinone_AI/blob/master/AIOAI_%EC%8B%AC%ED%99%94_day1_(%EC%99%84%EC%84%B1%EB%B3%B8)_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 그래프 그리기

# %% [markdown]
# ### 그래프를 그려주는 라이브러리
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/47_%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC.png?raw=true' width=500>
#
# </br>
# </br>
# </br>
#
# > 라이브러리는 다양한 명령어를 포함하고 있다. </br>
# > ex. operator 라이브러리 : 각종 연산자 명령어들 집합</br>
# > ex. tkinter 라이브러리 : 화면을 구성하는 다양한 명령어들 집합 (텍스트, 버튼, 콤보박스, 체크박스 등)</br>
#
# </br>
# </br>
#
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/63_%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC%20matplotlib.png?raw=true' width = 500>
#
# </br>
# </br>
# </br>
#
# > 라이브러리 포함하는 방법 </br></br>
# > import 라이브러리명 as 닉네임</br></br>
# > 닉네임.명령어A()</br>
# > 닉네임.명령어B()</br>

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4,5])

# %%
plt.plot([1,2,3,4,5])
plt.show()

# %%
a = [1,2,3,4,5]
plt.plot(a)
plt.show()

# %% [markdown]
# #### 실습 1 : 매출그래프 그리기
#
# ```
# 1-5월 매출이 다음과 같을 때, sales 변수에 넣어 매출 그래프를 그려보시오
#
# 1월 = 1
# 2월 = 5
# 3월 = 7
# 4월 = 3
# 5월 = 7
# ```

# %%
sales = [1,5,7,3,7]

# 매출그래프
plt.plot(sales)
plt.show()

# %% [markdown]
# ### x축 추가하기
#
#
# ```
# plt.plot(x축, y축)
# plt.show()
# ```

# %%
# x축 추가
mon = ['mar','apr','may','jun','jul']
sales = [1,5,7,3,7]

# X축, y축
plt.plot(mon, sales)
plt.show()

# %% [markdown]
# ### 그래프 제목 추가하기
#
#
# ```
# plt.title('제목')
# plt.plot(x축, y축)
# plt.show()
# ```

# %%
plt.title('monthly sales')
plt.plot(mon, sales)
plt.show()

# %%
plt.title('월별 판매 실적')
plt.plot(mon, sales)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49892 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# ### 코랩에서 한글 폰트 설정
# 1) 한글 폰트 코드 실행
#
# 2) 런타임 - 런타임 다시시작
#
# 3) 다시 한글폰트 실행
#
#
#
# ```
# # 한글 폰트 설정
# import matplotlib.pyplot as plt
# import matplotlib as mpl
# import matplotlib.pyplot as plt
#
# %config InlineBackend.figure_format = 'retina'
#
# !apt -qq -y install fonts-nanum
#
# import matplotlib.font_manager as fm
# fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# font = fm.FontProperties(fname=fontpath, size=9)
# plt.rc('font', family='NanumGothic')
# mpl.font_manager._rebuild()
# ```

# %%
# 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %%
mon = ['mar','apr','may','jun','jul']
sales = [1,5,7,3,7]

# 그래프 제목
plt.title('월별 판매 실적')
plt.plot(mon, sales)
plt.show()

# %% [markdown]
# ### 그래프 색상 변경
#
#
# ```
# # 그래프 그리는 명령어에 color 옵션 추가
# plt.plot(x축, y축, color = 'r')
# ```

# %%
plt.title('월별 판매 실적')
# 그래프 색상 변경
plt.plot(mon, sales, color ='r')
plt.show()

# %% [markdown]
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/22_%EA%B7%B8%EB%9E%98%ED%94%84%20%EC%BB%AC%EB%9F%AC.png?raw=true' width = 500>

# %% [markdown]
# #### 실습 2 : 원하는 색상으로 매출그래프 변경해보기

# %% [markdown]
# ### 해상도 설정 : 그래프를 선명하게
#
#
# ```
# plt.figure(dpi=해상도)
# plt.title('제목')
# plt.plot(x축, y축, color = '')
# plt.show()
# ```
# cf. dpi = dot per inch (1인치에 얼마나 많은 dot이 있는가) </br>
# <img src='https://y001224.cdn3.cafe24.com/dpi_explain_1.png' width = 200>
# <img src='https://www.pixtastock.com/blog/wp-content/uploads/2014/10/64' width = 300>
# <img src='https://files.cdn.printful.com/o/upload/file-upload/3f/3fb15e31bbc20b71c1241ecbcc564f88_l?v=cbdca71537087c51d8a806016f13c7d4' width=400>
# </br>
#  resolution = 해상도

# %%
# 해상도 설정 dpi = dot per inch
plt.figure(dpi=100)
plt.title('월별 판매 실적')
plt.plot(mon, sales, color ='b')
plt.show()

# %% [markdown]
# ### 범례 나타내기
#
#
# ```
# plt.plot(x축, y축, label = '범례 내용')
# plt.legend()      # 범례를 화면에 나타내기
# plt.show()
# ```

# %%
plt.figure(dpi=100)
plt.title('월별 판매 실적')
# 범례 label
plt.plot(mon, sales, color = 'b', label = '단위:개수')
# 범례를 화면에 나타내는 legend()
plt.legend()
plt.show()

# %% [markdown]
# ## 그래프 그리는 포맷
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.title('그래프 제목')
# plt.plot(x축 데이터, y축 데이터)
# plt.show()
# ```
#
# 그래프 명령어 plt.plot()의 추가옵션
#
#
# ```
# color = '색상이름'
# label = '범례내용'
# ```
#
# 기타 사용가능한 명령어
#
#
# ```
# plt.figure(dpi=150)     # 그래프 해상도 설정
# plt.legend()            # 범례 나타내기
# ```

# %% [markdown]
# # 2. 다양한 그래프
# ### plt.bar() : 막대그래프 - 세로형

# %%
plt.title('월별 판매 실적 막대그래프')
plt.bar(mon, sales, color = 'y')
plt.show()

# %% [markdown]
# ### plt.barh() : 막대그래프 - 가로형

# %%
plt.title('월별 판매 실적 가로형 막대그래프')
plt.barh(mon, sales, color = 'hotpink')
plt.show()

# %%
# plt.plot()처럼 y축 리스트만 넣어보기 
plt.bar(sales, color = 'y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-45b685d89b53> in <module>()
#       1 # plt.plot()처럼 y축 리스트만 넣어보기
# ----> 2 plt.bar(sales, color = 'y')
#       3 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
help(plt.bar)

# %% [markdown]
# plt.bar(), plt.barh()는 x축 리스트, y축 리스트 두 개 모두 넣어야 한다.

# %% [markdown]
# ### plt.hist() : 히스토그램

# %%
print(sales)
# Out:
# [1, 5, 7, 3, 7]

# %%
plt.title('판매 실적 히스토그램')
plt.hist(sales, color = 'skyblue')
plt.show()

# %% [markdown]
# ### plt.pie() : 원그래프
#
#
# ```
# 우리학교 100명의 혈액형을 조사한 결과가 다음과 같다.
#
# A형 = 28명
# B형 = 20명
# O형 = 40명
# AB형 = 12명
# ```

# %%
b_type = [28, 20, 40, 12]

plt.pie(b_type)
plt.show()

# %% [markdown]
# #### 원그래프 각 항목에 라벨 붙이기
#
#
# ```
# plt.pie(리스트, labels = 라벨리스트)
# ```

# %%
b_type = [25, 19, 37, 11]
b_name = ['A형', 'B형', 'O형', 'AB형']

plt.title('혈액형 비율')
plt.pie(b_type, labels = b_name)
plt.show()

# %% [markdown]
# #### 원그래프 항목에 퍼센트 표시
#
# ```
# plt.pie(리스트, labels = 라벨리스트, autopct = '%1.1f%%')
# ```

# %%
b_type = [25, 19, 37, 11]
b_name = ['A형', 'B형', 'O형', 'AB형']

plt.title('혈액형 비율')
plt.pie(b_type, labels = b_name, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### plt.scatter() : 산점도
#
# > 국어를 잘하는 친구가 영어도 잘할까? 같은 언어과목이긴 한데 과연 그럴까?
#
#
# ```
# 국어점수와 영어점수의 상관관계 알아보기
#
# kor =[80, 20, 50, 20, 10, 50, 60, 30, 60]
# eng =[90, 40, 60, 40, 10, 30, 50, 70, 90]
# ```

# %%
kor =[80, 20, 50, 20, 10, 50, 60, 30, 60]
eng =[90, 40, 60, 40, 10, 30, 50, 70, 90]

plt.scatter(kor, eng)
plt.show()

# %% [markdown]
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/23_scatter.png?raw=true' width=800>

# %% [markdown]
# #### x축 이름, y축 이름 붙이기
#
#
# ```
# plt.xlabel('x축 이름')
# plt.ylabel('y축 이름')
# ```

# %%
plt.title('국어점수와 영어점수와의 상관관계')
plt.scatter(kor, eng, c='indigo')
plt.xlabel('국어점수')
plt.ylabel('영어점수')
plt.show()

# %% [markdown]
# # 그래프 명령어 정리
# **그래프 그리는 포맷**
# ```
# import matplotlib.pyplot as plt
#
# plt.title('그래프 제목')
# # --- 그래프 형태에 따라 알맞은 명령어 넣기 ---
# plt.show()
# ```
#
#
# **그래프 유형별 명령어**
# ```
# # ---- 그래프 유형별 명령어
# # 꺾은선그래프
# plt.plot([x축 리스트], [y축 리스트])
#
# # 막대그래프 세로
# plt.bar([x축 리스트], [y축 리스트])
#
# # 막대그래프 가로
# plt.barh([x축 리스트], [y축 리스트])
#
# # 히스토그램 (x축, y축을 구분하지 않고 하나의 리스트만 넣음)
# plt.hist( [리스트], bins = 구간개수 )
#
# # 원 그래프 (x축, y축을 구분하지 않고 하나의 리스트만 넣음)
# plt.pie( [리스트], labels = [데이터 구간 이름])
#
# # 산점도
# plt.scatter([x축 리스트], [y축 리스트])
# ```
#
# **그래프 명령어 내에 추가 가능한 옵션**
#
# ```
# color = '색상이름'
# alpha = 투명도
#
# # plt.plot(), plt.bar(), plt.barh(), plt.scatter()는 label 사용
# label = '범례내용'
#
# # plt.pie(), plt.boxplot()은 labels 사용
# labels = [범례 리스트]
#
# # plt.pie()에 퍼센트 자동 표시
# autopct = ‘%1.1%%’
# ```
#
# **기타 사용가능한 명령어**
#
#
# ```
# plt.legend()            # 범례 나타내기
# plt.xlabel()            # x축 이름 붙이기
# plt.ylabel()            # y축 이름 붙이기
# ```

# %% [markdown]
# # 3. 이차원 리스트
# <img src ='https://github.com/Ahnjihye/allinone_AI/blob/images/14_%EC%9D%B4%EC%B0%A8%EC%9B%90%20%EB%A6%AC%EC%8A%A4%ED%8A%B8.png?raw=true' width=500>

# %%
abc = [[1,2,3], [4,5,6], [7,8,9]]
abc
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
abc[0]
# Out:
# [1, 2, 3]

# %%
abc[1]
# Out:
# [4, 5, 6]

# %%
for row in abc : 
    print(row)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %% [markdown]
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/16_%EC%9D%B4%EC%B0%A8%EC%9B%90%20%EB%A6%AC%EC%8A%A4%ED%8A%B8%20%EB%B0%98%EB%B3%B5%EA%B5%AC%EC%A1%B0.png?raw=true' width=700>

# %% [markdown]
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/15_%EC%9D%B4%EC%B0%A8%EC%9B%90%20%EB%A6%AC%EC%8A%A4%ED%8A%B8%20%EC%9D%B8%EB%8D%B1%EC%8A%A4.png?raw=true' width = 500>

# %%
# 5 출력하기
abc[0][0]
# Out:
# 1

# %%
# 7 출력하기
abc[1][2]
# Out:
# 6

# %% [markdown]
# #### 실습 3 : 반복문을 활용하여 이차원 리스트 abc의 첫번째 데이터(1, 4, 7)만 출력

# %%
# 반복문을 활용하여 모든 줄의 첫번째 데이터(1, 4, 7)만 출력
for row in abc : 
    print(row[0])
# Out:
# 1
# 4
# 7

# %% [markdown]
# #### 실습 4 : 반복문을 활용하여 이차원 리스트 abc의 마지막 데이터(3, 6, 9)만 출력

# %%
# 모든 줄의 마지막 데이터(3, 6, 9)만 출력
for row in abc : 
    print(row[-1])
# Out:
# 3
# 6
# 9

# %% [markdown]
# <img src= 'https://github.com/Ahnjihye/allinone_AI/blob/images/17_%EC%98%AC%EB%A6%BC%ED%94%BD.png?raw=true' width=500>
#
#
#
# ```
# olympic =[
#           [1,'미국',46,37,38,121],
#           [2,'영국',27,23,17,67],
#           [3,'중국',26,18,26,70],
#           [4,'러시아',19,18,19,56],
#           [5,'독일',17,10,15,42],
#           [6,'일본',12,8,21,41],
#           [7,'프랑스',10,18,14,42],
#           [8,'대한민국',9,3,9,21]
#         ]
# ```

# %%
olympic =[
          [1,'미국',46,37,38,121],
          [2,'영국',27,23,17,67],
          [3,'중국',26,18,26,70],
          [4,'러시아',19,18,19,56],
          [5,'독일',17,10,15,42],
          [6,'일본',12,8,21,41],
          [7,'프랑스',10,18,14,42],
          [8,'대한민국',9,3,9,21] 
        ]

# %% [markdown]
# #### 실습 5 : 2016년 올림픽 순위권에 든 모든 국가를 출력하시오

# %%
# 순위권에 든 모든 국가를 출력하시오
for row in olympic :
    print(row[1])
# Out:
# 미국
# 영국
# 중국
# 러시아
# 독일
# 일본
# 프랑스
# 대한민국

# %%
# 나라 이름에 글자 '국'이 들어간 모든 국가를 출력하시오
for row in olympic : 
    if '국' in row[1] : 
        print(row[1])
# Out:
# 미국
# 영국
# 중국
# 대한민국

# %% [markdown]
# #### 글자 포함 유무를 비교하는 연산자
#
#
# ```
# '글자' in '통글자'
# '글자' not in '통글자'
# ```
#
#
# ```
# if '국' in 000 :
#
# if '국' not in 000 :
# ```

# %% [markdown]
# #### 실습 6 : 나라이름에 글자 '국'이 들어가지 않은 모든 국가를 출력하기

# %%
# 나라 이름에 글자 '국'이 들어가지 않은 모든 국가를 출력하시오
for row in olympic : 
    if '국' not in row[1] : 
        print(row[1])
# Out:
# 러시아
# 독일
# 일본
# 프랑스

# %% [markdown]
# #### 실습 7 : 8개 국가의 총 금메달 개수 구하기

# %%
# 8개 국가의 총 금메달 개수를 구하시오
gold_sum =0

for row in olympic : 
    gold_sum += row[2]

print(gold_sum)
# Out:
# 166

# %% [markdown]
# #### 실습 8 : 금메달 개수보다 동메달 개수가 많은 나라를 출력하시오

# %%
# 금메달보다 동메달 개수가 많은 나라를 출력하시오
for row in olympic : 
    if row[2] < row[4] : 
        print(row[1])
# Out:
# 일본
# 프랑스

# %% [markdown]
# #### 실습 9 : x축은 국가명, y축은 금메달개수 꺾은선 그래프 그리기

# %%
# x축은 국가명, y축은 금메달개수 꺾은선 그래프 그리기 
nation = []
gold = []

for row in olympic : 
    nation.append(row[1])
    gold.append(row[2])

print(nation)
print(gold)
# Out:
# ['미국', '영국', '중국', '러시아', '독일', '일본', '프랑스', '대한민국']
# [46, 27, 26, 19, 17, 12, 10, 9]

# %%
import matplotlib.pyplot as plt

plt.title('나라별 금메달 추이')
plt.plot(nation, gold)
plt.show()

# %% [markdown]
# #### 실습 10 : x축은 국가명, y축은 금메달개수 막대 그래프 그리기 (x축, y축 이름 추가)

# %%
import matplotlib.pyplot as plt

plt.title('나라별 금메달 추이')
plt.bar(nation, gold, color ='crimson')
plt.xlabel('나라')
plt.ylabel('금메달 개수')
plt.show()

# %% [markdown]
# #### 실습 11: 아래 궁금증을 해결하는 그래프를 그려보자
# > 금메달이 많을수록 총 메달이 많을까? </br>
# > 어떤 그래프가 가장 잘 표현할 수 있을까?

# %%
gold = []
medal = []

for row in olympic : 
    gold.append(row[2])
    medal.append(row[-1])

print(gold)
print(medal)
# Out:
# [46, 27, 26, 19, 17, 12, 10, 9]
# [121, 67, 70, 56, 42, 41, 42, 21]

# %%
plt.title('금메달과 총 메달의 상관관계')
plt.scatter(gold, medal, color = 'indigo')
plt.xlabel('금메달 개수')
plt.ylabel('총 메달 개수')
plt.show()

# %% [markdown]
# # 4. 붓꽃 데이터 구분하기
#
# * 꽃 사진을 찍어서 품종을 알려주는 다음 꽃검색
#
# <img src='https://t1.daumcdn.net/cfile/tistory/991F18385BE2B58C25' width = 700>

# %% [markdown]
# ### 우리는 붓꽃의 품종을 구분해보자.
# <img src='https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png' width=600>
#
# 머신러닝 데이터가 많은 사이트 kaggle에서 붓꽃 데이터를 다운받아 실행해보기
#
#
#
# https://www.kaggle.com/uciml/iris

# %% [markdown]
# #### 1) 데이터 업로드

# %% [markdown]
# 업로드된 데이터를 리스트로 변환하기
# ```
# import csv
#
# f = open('파일명')
# data = csv.reader(f)
# next(data)
# data = list(data)
#
# ```

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab2b2c28-cdbd-43ff-8c6e-355f87495e3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab2b2c28-cdbd-43ff-8c6e-355f87495e3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris.csv

# %% [markdown]
# 업로드된 데이터를 리스트로 변환하기
# ```
# import csv
#
# f = open('파일명')
# data = csv.reader(f)
# next(data)
# data = list(data)
#
# ```

# %%
import csv 

f = open('iris.csv')
data = csv.reader(f)
next(data)
data = list(data)
# Out:
# 150

# %%
print(len(data))

# %%
print(data)

# %% [markdown]
# #### 2) csv 파일로 업로드하면 모두 문자로 인식. 문자로 저장된 숫자를 숫자 타입으로 변경해주기

# %%
for row in data : 
    row[1] = float(row[1])
    row[2] = float(row[2])
    row[3] = float(row[3])
    row[4] = float(row[4])

print(data)
# Out:
# [['1', 5.1, 3.5, 1.4, 0.2, 'setosa'], ['2', 4.9, 3.0, 1.4, 0.2, 'setosa'], ['3', 4.7, 3.2, 1.3, 0.2, 'setosa'], ['4', 4.6, 3.1, 1.5, 0.2, 'setosa'], ['5', 5.0, 3.6, 1.4, 0.2, 'setosa'], ['6', 5.4, 3.9, 1.7, 0.4, 'setosa'], ['7', 4.6, 3.4, 1.4, 0.3, 'setosa'], ['8', 5.0, 3.4, 1.5, 0.2, 'setosa'], ['9', 4.4, 2.9, 1.4, 0.2, 'setosa'], ['10', 4.9, 3.1, 1.5, 0.1, 'setosa'], ['11', 5.4, 3.7, 1.5, 0.2, 'setosa'], ['12', 4.8, 3.4, 1.6, 0.2, 'setosa'], ['13', 4.8, 3.0, 1.4, 0.1, 'setosa'], ['14', 4.3, 3.0, 1.1, 0.1, 'setosa'], ['15', 5.8, 4.0, 1.2, 0.2, 'setosa'], ['16', 5.7, 4.4, 1.5, 0.4, 'setosa'], ['17', 5.4, 3.9, 1.3, 0.4, 'setosa'], ['18', 5.1, 3.5, 1.4, 0.3, 'setosa'], ['19', 5.7, 3.8, 1.7, 0.3, 'setosa'], ['20', 5.1, 3.8, 1.5, 0.3, 'setosa'], ['21', 5.4, 3.4, 1.7, 0.2, 'setosa'], ['22', 5.1, 3.7, 1.5, 0.4, 'setosa'], ['23', 4.6, 3.6, 1.0, 0.2, 'setosa'], ['24', 5.1, 3.3, 1.7, 0.5, 'setosa'], ['25', 4.8, 3.4, 1.9, 0.2, 'setosa'], ['26', 5.0, 3.0, 1.6, 0.2, 'setosa'], ['27', 5.0, 3.4, 1
# ...

# %% [markdown]
# #### 3) x축이 꽃받침길이, y축이 꽃받침너비인 산점도 그려보기

# %%
import matplotlib.pyplot as plt

sepal_len =[]
sepal_wid =[]

for row in data : 
    sepal_len.append(row[1])
    sepal_wid.append(row[2])
    
plt.scatter(sepal_len, sepal_wid)
plt.xlabel('꽃받침 길이')
plt.ylabel('꽃받침 너비')
plt.show()

# %% [markdown]
# plt.scatter(x좌표, y좌표, color = )는 점 한 개를 찍는 것
#
# 여러 개의 점을 150번 반복해서 찍어보기

# %%
for row in data : 
    plt.scatter(row[1], row[2], color ='b')

plt.xlabel('꽃받침 길이')
plt.ylabel('꽃받침 너비')
plt.show()

# %% [markdown]
# #### 4) 품종별로 색상을 구분하여 찍어보자
#
#
# *   setosa는 indigo 색상
# *   versicolor는 crimson 색상
# *   virginica는 limegreen 색상

# %%
# 점 하나 찍을 때마다 품종을 구분하여 찍기
for row in data : 
    if row[-1] == 'setosa' : 
        plt.scatter(row[1], row[2], c = 'indigo')
    elif row[-1] == 'versicolor' : 
        plt.scatter(row[1], row[2], c = 'crimson')
    else : 
        plt.scatter(row[1], row[2], c = 'limegreen')

plt.xlabel('꽃받침 길이')
plt.ylabel('꽃받침 너비')
plt.show()

# %% [markdown]
# #### Q. 위 그래프는 붓꽃 품종 세 개를 잘 구분하나요?
#
# #### 그렇다면 그 이유는 무엇인지, 그렇지 않다면 그 이유는 무엇인가요?

# %% [markdown]
# #### 5) 꽃받침 길이가 다음과 같은 꽃이 인식되었을 때, 인공지능은 어떻게 판단할까요?
#
#
#
# 1.   꽃받침 길이 = 5, 꽃받침 너비 = 3.5
# 2.   꽃받침 길이 = 6.3, 꽃받침 너비 = 2.7
#
# ---
#
#
# 지금까지 작성한 그래프 위에 두 개 점을 파랑색 별로 찍어봅시다.
#
# - scatter 점 모양 변경 옵션 : marker = '*'
# - scatter 점 크기 변경 옵션 : s = 150

# %%
# 점 하나 찍을 때마다 품종을 구분하여 찍기
for row in data : 
    if row[-1] == 'setosa' : 
        plt.scatter(row[1], row[2], c = 'indigo')
    elif row[-1] == 'versicolor' : 
        plt.scatter(row[1], row[2], c = 'crimson')
    else : 
        plt.scatter(row[1], row[2], c = 'limegreen')

plt.scatter(5, 3.5, color ='b', marker='*', s=150)
plt.scatter(6.3, 2.7, color ='b', marker='*', s=150)

plt.xlabel('꽃받침 길이')
plt.ylabel('꽃받침 너비')
plt.show()

# %% [markdown]
# #### 6) 이번에는 꽃잎 길이가 x축, 꽃잎 너비가 y축인 산점도를 그려보자.
#
#
#
# *   setosa는 indigo 색상
# *   versicolor는 crimson 색상
# *   virginica는 limegreen 색상

# %%
# 점 하나 찍을 때마다 품종을 구분하여 찍기
for row in data : 
    if row[-1] == 'setosa' : 
        plt.scatter(row[3], row[4], c = 'indigo')
    elif row[-1] == 'versicolor' : 
        plt.scatter(row[3], row[4], c = 'crimson')
    else : 
        plt.scatter(row[3], row[4], c = 'limegreen')

plt.xlabel('꽃잎 길이')
plt.ylabel('꽃잎 너비')
plt.show()

# %% [markdown]
# #### Q. 위 그래프는 붓꽃 품종 세 개를 잘 구분하나요?
#
# #### 그렇다면 그 이유는 무엇인지, 그렇지 않다면 그 이유는 무엇인가요?

# %% [markdown]
# 꽃받침 길이가 다음과 같은 꽃이 인식되었을 때, 인공지능은 어떻게 판단할까요?
#
#
#
# 1.   꽃잎 길이 = 2, 꽃받침 너비 = 0.5
# 2.   꽃잎 길이 = 5.5, 꽃받침 너비 = 2.0
#
# ---
#
#
# 지금까지 작성한 그래프 위에 두 개 점을 파랑색 별로 찍어봅시다.
#
# - scatter 점 모양 변경 옵션 : marker = '*'
# - scatter 점 크기 변경 옵션 : s = 150

# %%
# 점 하나 찍을 때마다 품종을 구분하여 찍기
for row in data : 
    if row[-1] == 'setosa' : 
        plt.scatter(row[3], row[4], c = 'indigo')
    elif row[-1] == 'versicolor' : 
        plt.scatter(row[3], row[4], c = 'crimson')
    else : 
        plt.scatter(row[3], row[4], c = 'limegreen')

plt.scatter(2, 0.5, color ='b', marker='*', s=150)
plt.scatter(5.5, 2.0, color ='b', marker='*', s=150)

plt.xlabel('꽃잎 길이')
plt.ylabel('꽃잎 너비')
plt.show()

# %% [markdown]
# 7) 머신러닝 워밍업! 의사 결정 트리 만들어보기

# %% [markdown]
# #### 머신러닝 라이브러리 sklearn
# <img src='https://lh3.googleusercontent.com/proxy/rEQr3W9p9Q3LQLQao2DaMp2jioVL8tQ1Y2O_BT_szqFgcLn94sFUzqJ5GMArtE_DEGgD8vPMrTVwiG2bNGO64NF3aAnXKbZ91qRFSuTpBlcnuAi21RPEg-NUMeDvnxA8oa6IXdINTk7LVfD3Z47ROVpPPzo-jwjDrUcDV4AGJrcnfvPEEMrJXGVxwV-Ltrt-fpJACYPt2oFaO6raHywGiH6nF2r_vqPqQG1CcS_CJsYkFxwqJRZwz9Gx6xyCmCvE_kyGYYVgUy0TC4eyFbR0YfOb9K-VZSk6tkOZf6Gv4Q' width = 400>
#
#
# * 머신러닝에는 다양한 알고리즘이 존재
# * 대부분의 머신러닝 알고리즘이 sklearn에 구현되어 있음
# * sklearn의 의사결정트리를 사용하여 인공지능 학습을 시키고, 예측을 수행해보자

# %% [markdown]
# #### 인공지능 프로그래밍 - 간단한 순서
#
#
#
# 1.   인공지능 모델 생성하기
# 2.   모델에 데이터를 넣고 학습시키기
# 3.   새로운 데이터를 잘 예측하는지 확인해보기

# %%
# 1. 필요한 속성만 추출하기 - 꽃잎 길이, 꽃잎 너비
petal_len_wid = []
species = []

for row in data : 
    # iris 엑셀 데이터로 보여주기 -------------
    petal_len_wid.append([row[3], row[4]])
    species.append(row[5])

# %%
from sklearn.tree import DecisionTreeClassifier      # 의사결정트리 기능 포함시키기

# 2. 의사결정트리 모델 생성
model = DecisionTreeClassifier(max_depth= 2)         # 의사결정트리의 최대 깊이

# %%
# 3. data의 꽃잎길이와 꽃잎너비로 품종을 판별하도록 학습
model.fit(petal_len_wid, species)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# 새로운 데이터가 어떤 품종인지 맞혀보게 하기
# 1) 꽃잎 길이 = 2, 꽃받침 너비 = 0.5
model.predict([[2, 0.5]])
# Out:
# array(['setosa'], dtype='<U10')

# %%
# 2) 꽃잎 길이 = 5.5, 꽃받침 너비 = 2.0
model.predict([[5.5, 2.0]])
# Out:
# array(['virginica'], dtype='<U10')

# %% [markdown]
# ```
# import graphviz
# from sklearn.tree import export_graphviz
#
# # 의사 결정 트리를 시각화하여 tree.dot 파일로 내보내는 코드
# export_graphviz(model, out_file ='tree.dot',
#                 feature_names = [학습데이터 속성명],
#                 class_names = [학습결과로 판단할 분류],
#                 filled = True, rounded = True, impurity = False)
#
# # 위에서 만든 tree.dot을 화면에 보이게 하기
# with open("tree.dot") as f:
#     dot_graph = f.read()
# display(graphviz.Source(dot_graph))
# ```

# %%
import graphviz
from sklearn.tree import export_graphviz
 
# 의사 결정 트리를 시각화하여 tree.dot 파일로 내보내는 코드
export_graphviz(model, out_file ='tree.dot',
                feature_names = ['꽃잎 길이', '꽃잎 너비'],    
                class_names = ['setosa','versicolor','virginica'],
                filled = True, rounded = True, impurity = False)
 
# 위에서 만든 tree.dot을 화면에 보이게 하기
with open("tree.dot") as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %%
for row in data : 
    if row[-1] == 'setosa' : 
        plt.scatter(row[3], row[4], c = 'indigo')
    elif row[-1] == 'versicolor' : 
        plt.scatter(row[3], row[4], c = 'crimson')
    else : 
        plt.scatter(row[3], row[4], c = 'limegreen')

plt.xlabel('꽃잎 길이')
plt.ylabel('꽃잎 너비')
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahnjihye/allinone_AI/blob/master/AIO_AI_day5_(%EC%99%84%EC%84%B1%EB%B3%B8)_%EC%84%A0%ED%98%95_%ED%9A%8C%EA%B7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src= 'https://github.com/Ahnjihye/allinone_AI/blob/images/27_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B0%9C%EC%9A%94.png?raw=true' width=700>

# %% [markdown]
# ## 클래스와 객체

# %%
class human : 
    def sayhello(self) : 
        print('hello')
    def introduce(self, name, job) : 
        print('my name is',name,'and I am',job)

# %%
# 준일이라는 객체를 만든 것
JI = human()

# %%
JI.sayhello()
JI.introduce('joon','대학생')
# Out:
# hello
# my name is joon and I am 대학생

# %%
EK = human()
EK.introduce('은경','teacher')
# Out:
# my name is 은경 and I am teacher

# %% [markdown]
# ## numpy
# #### 여러 숫자의 계산을 한방에 처리해주는 numpy

# %%
# 모든 리스트 원소에 숫자 더하기
a = [1,2,3,4,5]
b = a+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-0480b337159c> in <module>()
#       1 # 모든 리스트 원소에 숫자 더하기
#       2 a = [1,2,3,4,5]
# ----> 3 b = a+2
#
# TypeError: can only concatenate list (not "int") to list

# %%
# 모든 리스트 원소에 숫자 곱하기
a = [1,2,3,4,5]
b = a*2

# %%
# 리스트를 넘파이로 변경해 처리해보자
import numpy as np

# 리스트타입 -> 넘파이 타입
a = np.array(a)
print(a)
# Out:
# [1 2 3 4 5]

# %%
b = a*2
print(b)
# Out:
# [ 2  4  6  8 10]

# %%
b = a*2+0.5
print(b)
# Out:
# [ 2.5  4.5  6.5  8.5 10.5]

# %% [markdown]
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C2.PNG?raw=true' width = 700>

# %% [markdown]
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C3.PNG?raw=true' width = 700>

# %% [markdown]
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C4.PNG?raw=true' width = 700>

# %% [markdown]
# # sklearn으로 일단 한번 머신러닝 모델 작성해보기

# %% [markdown]
# <img src ='https://github.com/Ahnjihye/allinone_AI/blob/images/28_%EB%8F%85%EB%A6%BD%EC%A2%85%EC%86%8D%EB%B3%80%EC%88%98.png?raw=true' width=700>

# %%
# 스몰 데이터
data = [[4, 16], [12, 42], [18, 50], [22, 75], [28, 70]]

# x 데이터와 y 데이터 분리
x, y = [], []
for d in data : 
    x.append(d[0])
    y.append(d[1])

print(x)
print(y)
# Out:
# [4, 12, 18, 22, 28]
# [16, 42, 50, 75, 70]

# %%
from sklearn.linear_model import LinearRegression

# 선형 회귀 객체 생성
model = LinearRegression()

# %%
# 학습
model.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-039ac26f08e6> in <module>()
#       1 # 학습
# ----> 2 model.fit(x, y)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     554                     "Reshape your data either using array.reshape(-1, 1) if "
#     555                     "your data has a single feature or array.reshape(1, -1) "
# --> 556                     "if it contains a single sample.".format(array))
#     557
#     558         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 4 12 18 22 28].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
x2 = []
for a in x : 
    x2.append([a])
print(x2)
# Out:
# [[4], [12], [18], [22], [28]]

# %%
# sklearn의 독립변수는 항상 이차원 리스트
model.fit(x2, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# 예측선 기울기
model.coef_
# Out:
# array([2.42840376])

# %%
# 예측선의 y절편
model.intercept_
# Out:
# 9.802816901408455

# %% [markdown]
# # 왜 이렇게 되는 거죠????

# %% [markdown]
# ## 1. 산점도를 그리는 함수 draw_graph() 만들기

# %%
import matplotlib.pyplot as plt

# 그래프 폰트 설정  --> 런타임 다시 시작
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# 선형 회귀를 학습할 스몰 데이터
data = [[4, 16], [12, 42], [18, 50], [22, 75], [28, 70]]
x, y = [], []

# 독립변수와 종속변수 분리
for d in data : 
    x.append(d[0])
    y.append(d[1])

print(x)
print(y)
# Out:
# [4, 12, 18, 22, 28]
# [16, 42, 50, 75, 70]

# %%
import matplotlib.pyplot as plt
# 마이너스 기호
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
 
def draw_graph(x_data, y_data, x_name, y_name) :     
    plt.scatter(x_data, y_data, color= 'r', alpha = 0.7)
    plt.xlabel(x_name)
    plt.ylabel(y_name)
    plt.grid(True)
    plt.show()

# %%
draw_graph(x, y, '스트레스 지수', '위장질환 확률(%)')

# %% [markdown]
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C5.PNG?raw=true' width = 700>

# %% [markdown]
# ## 2. 데이터를 관통하는 선 긋기

# %%
import numpy as np

def draw_graph_line(x_data, y_data, a, b, x_name, y_name) : 
    plt.scatter(x_data, y_data, color= 'r', alpha = 0.7)
    plt.xlabel(x_name)
    plt.ylabel(y_name)

    # 직선 추가
    # 리스트를 사칙연산이 되는 numpy로 바꿔줌
    x_data = np.array(x_data)
    y_line = a * x_data + b
    plt.plot(x_data, y_line, color = 'b')
    plt.grid(True)

    plt.show()

# %%
# y = 3x + 6
draw_graph_line(x, y, 3, 6, '스트레스 지수', '위장질환 발생률')

# %%
# y = 2x + 16
draw_graph_line(x, y, 2, 16, '스트레스 지수', '위장질환 발생률')

# %% [markdown]
# ## 3. 오차 계산하기 - 평균 제곱 오차 MSE

# %% [markdown]
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C8.PNG?raw=true' width = 700>

# %% [markdown]
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C9.PNG?raw=true' width = 700>
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C10.PNG?raw=true' width = 700>
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C11.PNG?raw=true' width = 700>
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C12.PNG?raw=true' width = 700>
#
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/%EC%8A%AC%EB%9D%BC%EC%9D%B4%EB%93%9C13.PNG?raw=true' width = 700>
#
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/26_MSE%EC%88%98%EC%8B%9D.png?raw=true' width = 500>

# %%
def mse(x_data, y_data, a, b) : 
    # 편리한 계산을 위해 리스트 --> numpy
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    
    # 예측값 y_predict
    y_predict = a * x_data + b

    # 오차 = 실제값 - 예측값
    error = (y_data - y_predict)

    # 오차의 제곱
    square_error = error ** 2

    # 평균 제곱 오차 : 오차제곱합 / n
    mean_square_error = square_error.sum() / len(error)

    print(a,'x+', b,'의 평균제곱오차 =', mean_square_error)
    return mean_square_error

# %%
mse(x, y, 3, 6)
mse(x, y, 2, 16)
# Out:
# 3 x+ 6 의 평균제곱오차 = 102.6
# 2 x+ 16 의 평균제곱오차 = 60.2
# 60.2

# %%
mse(x, y, -3, 6)
mse(x, y, 0, 6)
mse(x, y, 3, 6)
mse(x, y, 6, 6)
mse(x, y, 9, 6)
# Out:
# -3 x+ 6 의 평균제곱오차 = 11080.2
# 0 x+ 6 의 평균제곱오차 = 2437.8
# 3 x+ 6 의 평균제곱오차 = 102.6
# 6 x+ 6 의 평균제곱오차 = 4074.6
# 9 x+ 6 의 평균제곱오차 = 14353.8
# 14353.8

# %% [markdown]
# # g(x) = 2x+16 보다 오차가 더 작은 예측선은 없을까???
# #### 있다면 어떻게 알 수 있을까?
# ## 4. 손실함수(오차그래프)
# #### 오차가 가장 적은 기울기값은? y절편은?
#
# 오차 그래프 그려 오차를 최소화하는 지점 찾기

# %% [markdown]
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/29_a_list.png?raw=true' width = 700>

# %%
# 기울기와 y절편을 각각 리스트 인자로 받는 함수
def loss_function(x_data, y_data, a_list, b_list) : 
    # 기울기 리스트 a_list 원소별 오차를 저장할 리스트 
    loss_list = []
    
    for i in range(len(a_list)) : 
        loss_list.append(mse(x_data, y_data, a[i], b[i]))

    return loss_list

# %%
# -10부터 10까지 -0.5간격으로 기울기 리스트 만들기
a = np.arange(-10, 10, 0.5)
# 기울기 리스트 a와 같은 개수만큼 0을 채우기
b = np.full_like(a, 0)

loss_list = loss_function(x, y, a, b)
draw_graph(a, loss_list, '기울기','오차')
# Out:
# -10.0 x+ 0.0 의 평균제곱오차 = 58361.0
# -9.5 x+ 0.0 의 평균제곱오차 = 53929.0
# -9.0 x+ 0.0 의 평균제곱오차 = 49672.2
# -8.5 x+ 0.0 의 평균제곱오차 = 45590.6
# -8.0 x+ 0.0 의 평균제곱오차 = 41684.2
# -7.5 x+ 0.0 의 평균제곱오차 = 37953.0
# -7.0 x+ 0.0 의 평균제곱오차 = 34397.0
# -6.5 x+ 0.0 의 평균제곱오차 = 31016.2
# -6.0 x+ 0.0 의 평균제곱오차 = 27810.6
# -5.5 x+ 0.0 의 평균제곱오차 = 24780.2
# -5.0 x+ 0.0 의 평균제곱오차 = 21925.0
# -4.5 x+ 0.0 의 평균제곱오차 = 19245.0
# -4.0 x+ 0.0 의 평균제곱오차 = 16740.2
# -3.5 x+ 0.0 의 평균제곱오차 = 14410.6
# -3.0 x+ 0.0 의 평균제곱오차 = 12256.2
# -2.5 x+ 0.0 의 평균제곱오차 = 10277.0
# -2.0 x+ 0.0 의 평균제곱오차 = 8473.0
# -1.5 x+ 0.0 의 평균제곱오차 = 6844.2
# -1.0 x+ 0.0 의 평균제곱오차 = 5390.6
# -0.5 x+ 0.0 의 평균제곱오차 = 4112.2
# 0.0 x+ 0.0 의 평균제곱오차 = 3009.0
# 0.5 x+ 0.0 의 평균제곱오차 = 2081.0
# 1.0 x+ 0.0 의 평균제곱오차 = 1328.2
# 1.5 x+ 0.0 의 평균제곱오차 = 750.6
# 2.0 x+ 0.0 의 평균제곱오차 = 348.2
# 2.5 x+ 0.0 의 평균제곱오차 = 121.0
# 3.0 x+ 0.0 의 평균제곱오차 = 69.0
# 3.5 x+ 0.0 의 평균제곱오차 = 192.2
# 4.0 x+ 0.0 의 평균제곱오차 = 490.6
# 4.5 x+ 0.0 의 평균제곱오차 = 964.2
# 5.0 x+ 0.0 의 평균제곱오차 = 1613.0
# 5.5 x+ 0.0 의 평균제곱오차 = 2437.0
# 6.0 x+ 0.0 의 평균제곱오차 = 3436.2
# 6.5 x+ 0.0 의 평균제곱오차 = 4610.6
# 7.0 x+ 0.0 의 평균제곱오차 = 5960.2
# 7.5 x+ 0.0 의 평균제곱오차 = 7485.0
# 8.0 x+ 0.0 의 평균제곱오차 = 9185.0
# 8.5 x+ 0.0 의 평균제곱오차 = 11060.2
# 9.0 x+ 0.0 의 평균제곱오차 = 13110.6
# 9.5 x+ 0.0 의 평균제곱오차 = 15336.2

# %% [markdown]
# 그림
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/30_b_list.png?raw=true' width=700>

# %%
# -10부터 10까지 -0.5간격으로 y절편 리스트 만들기
b = np.arange(-10, 10, 0.5)
# y절편 리스트 b와 같은 개수만큼 0을 채우기
a = np.full_like(b, 3)

loss_list = loss_function(x, y, a, b)
draw_graph(b, loss_list, 'y절편','오차')
# Out:
# 3.0 x+ -10.0 의 평균제곱오차 = 173.0
# 3.0 x+ -9.5 의 평균제곱오차 = 163.05
# 3.0 x+ -9.0 의 평균제곱오차 = 153.6
# 3.0 x+ -8.5 의 평균제곱오차 = 144.65
# 3.0 x+ -8.0 의 평균제곱오차 = 136.2
# 3.0 x+ -7.5 의 평균제곱오차 = 128.25
# 3.0 x+ -7.0 의 평균제곱오차 = 120.8
# 3.0 x+ -6.5 의 평균제곱오차 = 113.85
# 3.0 x+ -6.0 의 평균제곱오차 = 107.4
# 3.0 x+ -5.5 의 평균제곱오차 = 101.45
# 3.0 x+ -5.0 의 평균제곱오차 = 96.0
# 3.0 x+ -4.5 의 평균제곱오차 = 91.05
# 3.0 x+ -4.0 의 평균제곱오차 = 86.6
# 3.0 x+ -3.5 의 평균제곱오차 = 82.65
# 3.0 x+ -3.0 의 평균제곱오차 = 79.2
# 3.0 x+ -2.5 의 평균제곱오차 = 76.25
# 3.0 x+ -2.0 의 평균제곱오차 = 73.8
# 3.0 x+ -1.5 의 평균제곱오차 = 71.85
# 3.0 x+ -1.0 의 평균제곱오차 = 70.4
# 3.0 x+ -0.5 의 평균제곱오차 = 69.45
# 3.0 x+ 0.0 의 평균제곱오차 = 69.0
# 3.0 x+ 0.5 의 평균제곱오차 = 69.05
# 3.0 x+ 1.0 의 평균제곱오차 = 69.6
# 3.0 x+ 1.5 의 평균제곱오차 = 70.65
# 3.0 x+ 2.0 의 평균제곱오차 = 72.2
# 3.0 x+ 2.5 의 평균제곱오차 = 74.25
# 3.0 x+ 3.0 의 평균제곱오차 = 76.8
# 3.0 x+ 3.5 의 평균제곱오차 = 79.85
# 3.0 x+ 4.0 의 평균제곱오차 = 83.4
# 3.0 x+ 4.5 의 평균제곱오차 = 87.45
# 3.0 x+ 5.0 의 평균제곱오차 = 92.0
# 3.0 x+ 5.5 의 평균제곱오차 = 97.05
# 3.0 x+ 6.0 의 평균제곱오차 = 102.6
# 3.0 x+ 6.5 의 평균제곱오차 = 108.65
# 3.0 x+ 7.0 의 평균제곱오차 = 115.2
# 3.0 x+ 7.5 의 평균제곱오차 = 122.25
# 3.0 x+ 8.0 의 평균제곱오차 = 129.8
# 3.0 x+ 8.5 의 평균제곱오차 = 137.85
# 3.0 x+ 9.0 의 평균제곱오차 = 146.4
# 3.0 x+ 9.5 의 평균제곱오차 = 155.45

# %% [markdown]
# ## 5. 경사 하강시키기

# %% [markdown]
# #### 5-1. 현재 기울기 구하기
#
#
# 1.   기울기 a에 대한 미분값 구하기
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/31_a%EB%AF%B8%EB%B6%84.png?raw=true' width =700>
#
# 2.   y절편 b에 대한 미분값 구하기
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/32_b%EB%AF%B8%EB%B6%84.png?raw=true' width=700 >

# %%
def gradient(x_data, y_data, a, b) : 
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    y_predict = a * x_data + b 
    loss = y_predict- y_data

    # 현재 손실함수에서 a의 기울기
    a_gradient = (2/len(x_data))*sum(loss * x_data)

    # 현재 손실함수에서 b의 기울기
    b_gradient = (2/len(x_data))*sum(loss)

# %% [markdown]
# #### 5-2. 현재 기울기의 반대방향으로 움직이자
#
# <img src = 'https://github.com/Ahnjihye/allinone_AI/blob/images/33_%EC%98%A4%EC%B0%A8%EA%B7%B8%EB%9E%98%ED%94%84.png?raw=true' width=400>
#
# #### 5-3. 한번 움직일 때 얼마나 이동할 지 비율을 정하자 (학습률)
#
# #### 5-4. 현재 기울기에서 -학습률*미분값 만큼 빼주기 (반대방향)

# %%
def gradient(x_data, y_data, a, b, lr) : 
    x_data = np.array(x_data)
    y_data = np.array(y_data)
    y_predict = a * x_data + b 
    loss = y_predict - y_data

    # 현재 손실함수에서 a의 기울기
    a_gradient = (2/len(x_data))*sum(loss * x_data)

    # 현재 손실함수에서 b의 기울기
    b_gradient = (2/len(x_data))*sum(loss)
    
    # 수정된 기울기와 y절편
    a = a - lr * a_gradient
    b = b - lr * b_gradient
    return a, b

# %% [markdown]
# #### 경사 하강을 반복하기 -> 오차가 가장 적을 때까지

# %%
# 최적을 어디로 볼 것인가? 기울기 두 자리수가 10번이상 나오면 최적이라고 간주
epochs = 12001   # 1000부터 늘려가기
lr = 0.001       
a, b = 0, 0     # 기울기, y절편 

for i in range(epochs) : 
    a, b = gradient(x, y, a, b, lr)

    if i % 100 == 0 :
        print('학습 횟수', i, '기울기', a, 'y절편', b)
# Out:
# 학습 횟수 0 기울기 2.0312 y절편 0.1012
# 학습 횟수 100 기울기 2.8741805554397963 y절편 0.5103361391734037
# 학습 횟수 200 기울기 2.857206070483429 y절편 0.8641793070044758
# 학습 횟수 300 기울기 2.8408779474279306 y절편 1.204548679126486
# 학습 횟수 400 기울기 2.8251715738206715 y절편 1.5319573166560956
# 학습 횟수 500 기울기 2.810063274412814 y절편 1.846898744143198
# 학습 횟수 600 기울기 2.795530275472055 y절편 2.1498476934929056
# 학습 횟수 700 기울기 2.7815506704542816 y절편 2.4412608195601333
# 학습 횟수 800 기울기 2.7681033869823994 y절편 2.721577388495464
# 학습 횟수 900 기울기 2.7551681550825533 y절편 2.9912199398798824
# 학습 횟수 1000 기울기 2.7427254766298628 y절편 3.250594923646441
# 학습 횟수 1100 기울기 2.7307565959576205 y절편 3.500093312748946
# 학습 횟수 9600 기울기 2.439556585596513 y절편 9.570329576380965
# 학습 횟수 9700 기울기 2.4391319032428775 y절편 9.579182330954596
# 학습 횟수 9800 기울기 2.4387233921306115 y절편 9.587697986447532
# 학습 횟수 9900 기울기 2.4383304364840765 y절편 9.595889379066765
# 학습 횟수 10000 기울기 2.4379524439754103 y절편 9.60376885623658
# 학습 횟수 10100 기울기 2.4375888448316707 y절편 9.611348295210549
# 학습 횟수 10200 기울기 2.437239090975981 y절편 9.618639120975025
# 학습 횟수 10300 기울기 2.436902655201374 y절편 9.625652323470685
# 학습 횟수 10400 기울기 2.4365790303761035 y절편 9.632398474158427
# 학습 횟수 10500 기울기 2.436267728679209 y절편 9.63888774195439
# 학습 횟수 10600 기울기 2.4359682808651897 y절편 9.645129908558264
# 학습 횟수 10700 기울기 2.435680235556683 y절편 9.651134383197867
# 학습 횟수 10800 기울기 2.4354031585640703 y절편 9.656910216812339
# 학습 횟수 10900 기울기 2.4351366322309973 y절편 9.662466115695121
# 학습 횟수 11000 기울기 2.4348802548048116 y절편 9.667810454617642
# 학습 횟수 11100 기울기 2.4346336398309734 y절편 9.672951289453081
# 학습 횟수 11200 기울기 2.4343964155705318 y절편 9.677896369319527
# 학습 횟수 11300 기울기 2.4341682244397735 y절편 9.682653148260746
# 학습 횟수 11400 기울기 2.4339487224712144 y절편 9.687228796482161
# 학습 횟수 11500 기울기 2.433737578795117 y절편 9.691630211158953
# 학습 횟수 11600 기울기 2.4335344751407457 y절편 9.695864026832627
# 학습 횟수 11700 기울기 2.433339105356618 y절편 9.699936625411725
# 학습 횟수 11800 기울기 2.433151174949023 y절편 9.703854145791645
# 학습 횟수 11900 기울기 2.4329704006381108 y절편 9.707622493108229
# 학습 횟수 12000 기울기 2.4327965099308853 y절편 9.711247347638961

# %%
# 최적을 어디로 볼 것인가? 기울기 두 자리수가 10번이상 나오면 최적이라고 간주
epochs = 5001   # 1000부터 늘려가기
lr = 0.0025     
a, b = 0, 0     # 기울기, y절편 

for i in range(epochs) : 
    a, b = gradient(x, y, a, b, lr)

    if i % 100 == 0 :
        print('학습 횟수', i, '기울기', a, 'y절편', b)
# Out:
# 학습 횟수 0 기울기 5.078 y절편 0.253
# 학습 횟수 100 기울기 2.848705936507031 y절편 1.0413696218495223
# 학습 횟수 200 기울기 2.8098194083110766 y절편 1.8519822771156047
# 학습 횟수 300 기울기 2.7745306774745804 y절편 2.5875967207951116
# 학습 횟수 400 기울기 2.7425068743254397 y절편 3.2551518178374046
# 학습 횟수 500 기울기 2.713445926430021 y절편 3.8609444465929363
# 학습 횟수 600 기울기 2.6870737092187444 y절편 4.410688895673647
# 학습 횟수 700 기울기 2.6631414602383767 y절편 4.909570765391835
# 학습 횟수 800 기울기 2.64142343263873 y절편 5.362295882216021
# 학습 횟수 900 기울기 2.621714765759745 y절편 5.773134687641546
# 학습 횟수 1000 기울기 2.6038295527327056 y절편 6.14596252018485
# 학습 횟수 1100 기울기 2.5875990868677783 y절편 6.484296170471282
# 학습 횟수 1200 기울기 2.572870270286489 y절편 6.791327054231408
# 학습 횟수 1300 기울기 2.5595041697881626 y절편 7.069951316118212
# 학습 횟수 1400 기울기 2.547374706328191 y절편 7.322797148306924
# 학습 횟수 1500 기울기 2.5363674657463036 y절편 7.552249581566942
# 학습 횟수 1600 기울기 2.5263786195267315 y절편 7.760472982653685
# 학습 횟수 1700 기울기 2.5173139454100943 y절편 7.949431470232674
# 학습 횟수 1800 기울기 2.5090879386186544 y절편 8.12090744191399
# 학습 횟수 1900 기울기 2.5016230053113873 y절편 8.276518387158033
# 학습 횟수 2000 기울기 2.494848730660905 y절편 8.417732144644402
# 학습 횟수 2100 기울기 2.488701214648203 y절편 8.545880748022839
# 학습 횟수 2200 기울기 2.483122469309951 y절편 8.662172990649585
# 학습 횟수 2300 기울기 2.478059871752699 y절편 8.76770582782942
# 학습 횟수 2400 기울기 2.4734656677744398 y절편 8.863474724117479
# 학습 횟수 2500 기울기 2.469296521411301 y절편 8.95038304328454
# 학습 횟수 2600 기울기 2.4655131061603606 y절편 9.029250569519016
# 학습 횟수 2700 기울기 2.462079734022697 y절편 9.100821240243747
# 학습 횟수 2800 기울기 2.4589640188675177 y절편 9.165770163489531
# 학습 횟수 2900 기울기 2.4561365709419887 y절편 9.224709986018377
# 학습 횟수 3000 기울기 2.453570719645121 y절편 9.278196672265455
# 학습 횟수 3100 기울기 2.4512422619507497 y절편 9.326734748610917
# 학습 횟수 3200 기울기 2.4491292341065023 y절편 9.37078206244963
# 학습 횟수 3300 기울기 2.447211704455286 y절편 9.410754100949807
# 학습 횟수 3400 기울기 2.4454715854249995 y절편 9.44702791023842
# 학습 횟수 3500 기울기 2.4438924629130523 y절편 9.479945651981803
# 학습 횟수 3600 기울기 2.4424594414562804 y절편 9.509817830910212
# 학습 횟수 3700 기울기 2.44115900372581 y절편 9.53692622373033
# 학습 횟수 3800 기울기 2.43997888302152 y절편 9.561526537053684
# 학습 횟수 3900 기울기 2.438907947563356 y절편 9.583850819412381
# 학습 횟수 4000 기울기 2.4379360954880696 y절편 9.60410965011426
# 학습 횟수 4100 기울기 2.437054159560895 y절편 9.6224941255842
# 학습 횟수 4200 기울기 2.436253820703349 y절편 9.639177661928349
# 학습 횟수 4300 기울기 2.435527529521458 y절편 9.654317630724389
# 학습 횟수 4400 기울기 2.434868435094242 y절편 9.668056843467829
# 학습 횟수 4500 기울기 2.4342703203507083 y절편 9.680524898676692
# 학습 횟수 4600 기울기 2.433727543425797 y절편 9.691839404361549
# 학습 횟수 4700 기울기 2.4332349844420866 y절편 9.70210708739217
# 학습 횟수 4800 기울기 2.432787997215292 y절편 9.711424800225014
# 학습 횟수 4900 기울기 2.432382365427984 y절편 9.719880434488028
# 학습 횟수 5000 기울기 2.4320142628581296 y절편 9.72755375004009

# %%
draw_graph_line(x, y, a, b, '스트레스 지수', '위장질환 발생률')
print(a,'x+',b)
# Out:
# 2.4320142628581296 x+ 9.72755375004009

# %% [markdown]
# ## 6. 데이터 개수 늘려보기
#
# 참고
#
#
# ```
# # 깃허브 레파지토리 클론
# !git clone ~~
#
# # 클론한 깃허브 레파지토리 삭제
# rm -rd allinone_AI
#
# # 클론되었는지 확인
# ls
# ```

# %%
# !git clone https://github.com/Ahnjihye/allinone_AI.git
# Out:
# fatal: destination path 'allinone_AI' already exists and is not an empty directory.

# %%
import csv

f = open('allinone_AI/shoes and height.csv', encoding='cp949')
data = csv.reader(f)
next(data)
data=list(data)

# %%
# 독립변수와 종속변수의 분리
X, y =[], []
for row in data : 
    X.append(int(row[1]))     # 신발 크기
    y.append(int(row[2]))     # 키

# %%
epochs = 101   # 학습 반복 횟수 
lr = 0.00001       # 학습률
a, b = 1, 0     # 기울기, y절편 

for i in range(epochs) : 
    a, b = gradient(X, y, a, b, lr)

    if i % 10 == 0 :
        print('학습 횟수', i, '기울기', a, 'y절편', b)
# Out:
# 학습 횟수 0 기울기 0.5748966666666666 y절편 -0.0016660000000000002
# 학습 횟수 10 기울기 0.6713587513619161 y절편 -0.0012743609262519948
# 학습 횟수 20 기울기 0.6713591570658392 y절편 -0.0012610614793109678
# 학습 횟수 30 기울기 0.6713591049123466 y절편 -0.0012477638416639502
# 학습 횟수 40 기울기 0.6713590527567339 y절편 -0.0012344662175222038
# 학습 횟수 50 기울기 0.671359000601174 y절편 -0.001221168606877193
# 학습 횟수 60 기울기 0.6713589484456672 y절편 -0.0012078710097289023
# 학습 횟수 70 기울기 0.6713588962902132 y절편 -0.00119457342607732
# 학습 횟수 80 기울기 0.6713588441348123 y절편 -0.0011812758559224313
# 학습 횟수 90 기울기 0.6713587919794641 y절편 -0.0011679782992642226
# 학습 횟수 100 기울기 0.671358739824169 y절편 -0.0011546807561026802

# %%
draw_graph_line(X, y, a, b, '신발크기', '키')
print(a,'x+',b)
# Out:
# 0.671358739824169 x+ -0.0011546807561026802

# %% [markdown]
# ## 3차원 데이터

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False   

def draw_3D_graph(x1_data, x2_data, y_data, a, b, c, x1_name, x2_name, y_name) : 
    x1_data = np.array(x1_data, dtype=np.float64)
    x2_data = np.array(x2_data, dtype=np.float64)
    y_data = np.array(y_data, dtype=np.float64)
    
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(111, projection='3d') # Axe3D object
    ax.scatter(x1_data, x2_data, y_data, alpha=0.7)
    ax.set_xlabel(x1_name)
    ax.set_ylabel(x2_name)
    ax.set_zlabel(y_name)  

    x1_data, x2_data = np.meshgrid(x1_data, x2_data)
    z = a*x1_data + b*x2_data + c

    ax.contour3D(x1_data, x2_data, z, 80)
    plt.show()

# %%
f = open('allinone_AI/stress, junkfood, illness.csv')
data = csv.reader(f)
next(data)
data=list(data)

# %%
x, y = [],[]
for row in data : 
    x.append(row[:2])
    y.append(row[-1])

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x, y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:755: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   estimator=estimator)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# 기울기
model.coef_
# Out:
# array([1.41149057, 2.37325548])

# %%
# y절편
model.intercept_
# Out:
# 77.1632171413685

# %%
x1, x2 = [], []
for row in x : 
    x1.append(row[0])
    x2.append(row[1])

draw_3D_graph(x1, x2, y, model.coef_[0], model.coef_[1], model.intercept_, 
              '스트레스 지수', '인스턴트 음식', '위장질환 발생지수')

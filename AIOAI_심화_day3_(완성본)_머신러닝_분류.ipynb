# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahnjihye/allinone_AI/blob/master/AIOAI_%EC%8B%AC%ED%99%94_day3_(%EC%99%84%EC%84%B1%EB%B3%B8)_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EB%B6%84%EB%A5%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 인공지능이란?
#  : 인간의 지능을 인공적으로 모방하는 총체
#
#  <img src='https://miro.medium.com/max/1000/0*lOPl0881zcdhdHnl.png' width=700>
#
#
#
# > 인공지능(Artificial Intelligence)
#
# : 가장 오래된 개념으로 인간의 지능을 컴퓨터 프로그램으로 구현해 인공적인 지능을 갖춘 컴퓨터 시스템이다.
#
#   * Q. 인공지능의 사례 ? 계산 기능을 모방한 계산기, 일정관리 앱,
#   * 또 다른 인공지능의 사례를 생각해봅시다
#
# > 머신러닝 (Machine Learning)
#
# : 말 그대로 기계(Machine)가 스스로 학습(Learning)을 하는 것으로 인간이 직접 지시를(프로그래밍) 하는 것이 아니고, 데이터와 원하는 결과 값을 주면 스스로 학습하여 조건을 찾는 것이다. 인간이 컴퓨터를 다루는 근본적인 개념을 바꾸었다는 측면에서 큰 의미를 지닌다.
#
# <img src='https://i0.wp.com/vinodsblog.com/wp-content/uploads/2018/11/Classification-vs-Regression.png?fit=2048%2C1158&ssl=1' width=600>
#
# --> [기존 프로그래밍과 인공지능의 차이](https://youtu.be/ZY6eBxyEOq0)
#
# > 딥러닝(Deep Learning)
#
# : 인간의 뇌 신경망을 모방한 인공 신경망의 한 종류로 예전부터 존재했으나, 근본적인 한계로 인해 사라질 뻔하다가 2000년대 들어 기존 한계를 극복할 알고리즘을 찾아 ‘딥러닝’이라는 새로운 이름으로 브랜딩 하였다. 근래 들어 축적된 막대한 데이터와 그래픽 처리 장치의 발전으로 정확도가 급격히 좋아져서 현재는 활발히 이용되고 있다.
#
#
# * 신경세포 뉴런
#
# <img src='https://thumbs.gfycat.com/BrightElatedAlbino-small.gif' width=400>
#
# * 서로 상호작용하는 뉴런
#
# <img src='https://media2.giphy.com/media/9N2UvCx7wXLnG/giphy.gif' width=600>
#
# * 뉴런을 모방한 인공신경망
#
# <img src='https://thumbs.gfycat.com/ActiveCourteousAmericanindianhorse-small.gif' width=600>

# %% [markdown]
# # 2. 머신러닝과 딥러닝의 차이
#
# <img src='https://blog.kakaocdn.net/dn/LYTie/btqDp12Zbvq/YyvsPGwZYfnvVcHfi9kTE0/img.jpg' width=600>
#
#
# <img src='https://kr.mathworks.com/solutions/image-video-processing/object-recognition/_jcr_content/mainParsys/band_copy_copy_14735_1351083864/mainParsys/columns_1606542234_c_508428977/2/image_copy_copy_copy.adapt.480.high.svg/1599565806635.svg' width=600>
#
#
#
#
# <img src='https://lh3.googleusercontent.com/proxy/HdnSDgPqfSxrL0pojlR5UH4X1UblMq3eJqI-io1NPK7SPdn2qcl3GasCCKHg6V6UA4DcA0N4vJ1DIBuNF2oBtjo5WQRNCKf_lg7opCAmd0AtPuSLzJW7HwO0' width=600>

# %% [markdown]
# # 3. 지도학습, 비지도학습
#
# <img src='https://nohjiho.github.io/images/ml/tensorflow/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EC%9C%A0%ED%98%95.png' width=1000>

# %% [markdown]
# # 4. 지도학습
# ## 분류와 회귀
#   *  분류 : 서로 다른 대상을 구분하는 것 (결과값이 구분적인 값)
#   *  회귀 : 새로운 데이터의 예측값을 구하는 것 (결과값이 연속적인 값)
#
# <img src='https://i0.wp.com/vinodsblog.com/wp-content/uploads/2018/11/Classification-vs-Regression.png?fit=2048%2C1158&ssl=1' width=600>
#
#
#
#   * Q. 분류로 해결할 수 있는 문제에는 무엇이 있을까요?
#   * Q. 회귀로 해결할 수 있는 문제에는 무엇이 있을까요?

# %% [markdown]
# # 5. 분류 알고리즘
# ## 5-1. Decision Tree (의사결정트리)
# ## 5-2. KNN
#
# <img src='https://blog.kakaocdn.net/dn/cvzGSE/btqw569xJ8n/DfckialHS6fgKmDZpy4L01/img.png' width=600>
#
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FbIPgPh%2FbtqyUfXFHSg%2FzaSUkU4xoqEEAsOClKWvw1%2Fimg.png' width=800>

# %%
# 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %% [markdown]
# ## KNN 1) 붓꽃 데이터 KNN으로 분류해보기
#
#
# (1) 데이터 업로드 및 숫자로 변환
# ```
# from google.colab import files
# uploaded = files.upload()
# ```
#
#
#
# ```
# import csv
#
# f = open('파일명')
# data = csv.reader(f)
# next(data)
# data = list(data)
# ```

# %%
from google.colab import files
uploaded = files.upload()

import csv 
 
f = open('iris.csv')
data = csv.reader(f)
next(data)
data = list(data)
# Out:
#      <input type="file" id="files-57ddfda8-225c-4a78-99cb-b8d24a294703" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57ddfda8-225c-4a78-99cb-b8d24a294703">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris (1).csv

# %%
for row in data : 
    row[1] = float(row[1])
    row[2] = float(row[2])
    row[3] = float(row[3])
    row[4] = float(row[4])

print(data)
# Out:
# [['1', 5.1, 3.5, 1.4, 0.2, 'setosa'], ['2', 4.9, 3.0, 1.4, 0.2, 'setosa'], ['3', 4.7, 3.2, 1.3, 0.2, 'setosa'], ['4', 4.6, 3.1, 1.5, 0.2, 'setosa'], ['5', 5.0, 3.6, 1.4, 0.2, 'setosa'], ['6', 5.4, 3.9, 1.7, 0.4, 'setosa'], ['7', 4.6, 3.4, 1.4, 0.3, 'setosa'], ['8', 5.0, 3.4, 1.5, 0.2, 'setosa'], ['9', 4.4, 2.9, 1.4, 0.2, 'setosa'], ['10', 4.9, 3.1, 1.5, 0.1, 'setosa'], ['11', 5.4, 3.7, 1.5, 0.2, 'setosa'], ['12', 4.8, 3.4, 1.6, 0.2, 'setosa'], ['13', 4.8, 3.0, 1.4, 0.1, 'setosa'], ['14', 4.3, 3.0, 1.1, 0.1, 'setosa'], ['15', 5.8, 4.0, 1.2, 0.2, 'setosa'], ['16', 5.7, 4.4, 1.5, 0.4, 'setosa'], ['17', 5.4, 3.9, 1.3, 0.4, 'setosa'], ['18', 5.1, 3.5, 1.4, 0.3, 'setosa'], ['19', 5.7, 3.8, 1.7, 0.3, 'setosa'], ['20', 5.1, 3.8, 1.5, 0.3, 'setosa'], ['21', 5.4, 3.4, 1.7, 0.2, 'setosa'], ['22', 5.1, 3.7, 1.5, 0.4, 'setosa'], ['23', 4.6, 3.6, 1.0, 0.2, 'setosa'], ['24', 5.1, 3.3, 1.7, 0.5, 'setosa'], ['25', 4.8, 3.4, 1.9, 0.2, 'setosa'], ['26', 5.0, 3.0, 1.6, 0.2, 'setosa'], ['27', 5.0, 3.4, 1.6, 0.4, 'setosa'], ['28', 5.2, 3.5, 1.5, 0.2, 'setosa'], ['29', 5.2, 3.4, 1.4, 0.2, 'setosa'], ['30', 4.7, 3.2, 1.6, 0.2, 'setosa'], ['31', 4.8, 3.1, 1.6, 0.2, 'setosa'], ['32', 5.4, 3.4, 1.5, 0.4, 'setosa'], ['33', 5.2, 4.1, 1.5, 0.1, 'setosa'], ['34', 5.5, 4.2, 1.4, 0.2, 'setosa'], ['35', 4.9, 3.1, 1.5, 0.1, 'setosa'], ['36', 5.0, 3.2, 1.2, 0.2, 'setosa'], ['37', 5.5, 3.5, 1.3, 0.2, 'setosa'], ['38', 4.9, 3.1, 1.5, 0.1, 'setosa'], ['39', 4.4, 3.0, 1.3, 0.2, 'setosa'], ['40', 5.1, 3.4, 1.5, 0.2, 'setosa'], ['41', 5.0, 3.5, 1.3, 0.3, 'setosa'], ['42', 4.5, 2.3, 1.3, 0.3, 'setosa'], ['43', 4.4, 3.2, 1.3, 0.2, 'setosa'], ['44', 5.0, 3.5, 1.6, 0.6, 'setosa'], ['45', 5.1, 3.8, 1.9, 0.4, 'setosa'], ['46', 4.8, 3.0, 1.4, 0.3, 'setosa'], ['47', 5.1, 3.8, 1.6, 0.2, 'setosa'], ['48', 4.6, 3.2, 1.4, 0.2, 'setosa'], ['49', 5.3, 3.7, 1.5, 0.2, 'setosa'], ['50', 5.0, 3.3, 1.4, 0.2, 'setosa'], ['51', 7.0, 3.2, 4.7, 1.4, 'versicolor'], ['52', 6.4, 3.2, 4.5, 1.5, 'versicolor'], ['53', 6.9, 3.1, 4.9, 1.5, 'versicolor'], ['54', 5.5, 2.3, 4.0, 1.3, 'versicolor'], ['55', 6.5, 2.8, 4.6, 1.5, 'versicolor'], ['56', 5.7, 2.8, 4.5, 1.3, 'versicolor'], ['57', 6.3, 3.3, 4.7, 1.6, 'versicolor'], ['58', 4.9, 2.4, 3.3, 1.0, 'versicolor'], ['59', 6.6, 2.9, 4.6, 1.3, 'versicolor'], ['60', 5.2, 2.7, 3.9, 1.4, 'versicolor'], ['61', 5.0, 2.0, 3.5, 1.0, 'versicolor'], ['62', 5.9, 3.0, 4.2, 1.5, 'versicolor'], ['63', 6.0, 2.2, 4.0, 1.0, 'versicolor'], ['64', 6.1, 2.9, 4.7, 1.4, 'versicolor'], ['65', 5.6, 2.9, 3.6, 1.3, 'versicolor'], ['66', 6.7, 3.1, 4.4, 1.4, 'versicolor'], ['67', 5.6, 3.0, 4.5, 1.5, 'versicolor'], ['68', 5.8, 2.7, 4.1, 1.0, 'versicolor'], ['69', 6.2, 2.2, 4.5, 1.5, 'versicolor'], ['70', 5.6, 2.5, 3.9, 1.1, 'versicolor'], ['71', 5.9, 3.2, 4.8, 1.8, 'versicolor'], ['72', 6.1, 2.8, 4.0, 1.3, 'versicolor'], ['73', 6.3, 2.5, 4.9, 1.5, 'versicolor'], ['74', 6.1, 2.8, 4.7, 1.2, 'versicolor'], ['75', 6.4, 2.9, 4.3, 1.3, 'versicolor'], ['76', 6.6, 3.0, 4.4, 1.4, 'versicolor'], ['77', 6.8, 2.8, 4.8, 1.4, 'versicolor'], ['78', 6.7, 3.0, 5.0, 1.7, 'versicolor'], ['79', 6.0, 2.9, 4.5, 1.5, 'versicolor'], ['80', 5.7, 2.6, 3.5, 1.0, 'versicolor'], ['81', 5.5, 2.4, 3.8, 1.1, 'versicolor'], ['82', 5.5, 2.4, 3.7, 1.0, 'versicolor'], ['83', 5.8, 2.7, 3.9, 1.2, 'versicolor'], ['84', 6.0, 2.7, 5.1, 1.6, 'versicolor'], ['85', 5.4, 3.0, 4.5, 1.5, 'versicolor'], ['86', 6.0, 3.4, 4.5, 1.6, 'versicolor'], ['87', 6.7, 3.1, 4.7, 1.5, 'versicolor'], ['88', 6.3, 2.3, 4.4, 1.3, 'versicolor'], ['89', 5.6, 3.0, 4.1, 1.3, 'versicolor'], ['90', 5.5, 2.5, 4.0, 1.3, 'versicolor'], ['91', 5.5, 2.6, 4.4, 1.2, 'versicolor'], ['92', 6.1, 3.0, 4.6, 1.4, 'versicolor'], ['93', 5.8, 2.6, 4.0, 1.2, 'versicolor'], ['94', 5.0, 2.3, 3.3, 1.0, 'versicolor'], ['95', 5.6, 2.7, 4.2, 1.3, 'versicolor'], ['96', 5.7, 3.0, 4.2, 1.2, 'versicolor'], ['97', 5.7, 2.9, 4.2, 1.3, 'versicolor'], ['98', 6.2, 2.9, 4.3, 1.3, 'versicolor'], ['99', 5.1, 2.5, 3.0, 1.1, 'versicolor'], ['100', 5.7, 2.8, 4.1, 1.3, 'versicolor'], ['101', ...

# %% [markdown]
# (2) 데이터 시각화 - 꽃잎 길이를 가로축, 꽃잎 너비를 세로축으로 하는 산점도 그려보기 (색상을 그림 참고)
#
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/iris_1.png?raw=true' width = 500>
#
# <img src='https://github.com/Ahnjihye/allinone_AI/blob/images/iris_2.png?raw=true' width = 500>

# %%
# 점 하나 찍을 때마다 품종을 구분하여 찍기
for row in data : 
    if row[-1] == 'setosa' : 
        plt.scatter(row[3], row[4], c = 'indigo')
    elif row[-1] == 'versicolor' : 
        plt.scatter(row[3], row[4], c = 'crimson')
    else : 
        plt.scatter(row[3], row[4], c = 'limegreen')

plt.xlabel('꽃잎 길이')
plt.ylabel('꽃잎 너비')
plt.show()

# %% [markdown]
# (3) 새로운 붓꽃 그래프에 표현해보기
#
# 꽃받침 길이가 다음과 같은 꽃이 인식되었을 때, 인공지능은 어떻게 판단할까요?
#
# 1.   꽃잎 길이 = 2.5, 꽃받침 너비 = 0.75
# 2.   꽃잎 길이 = 5, 꽃받침 너비 = 1.75
#
# ---
#
#
# 지금까지 작성한 그래프 위에 두 개 점을 파랑색 별로 찍어봅시다.
#
# - scatter 점 모양 변경 옵션 : marker = '*'
# - scatter 점 크기 변경 옵션 : s = 150

# %%
for row in data : 
    if row[-1] == 'setosa' : 
        plt.scatter(row[3], row[4], c = 'indigo')
    elif row[-1] == 'versicolor' : 
        plt.scatter(row[3], row[4], c = 'crimson')
    else : 
        plt.scatter(row[3], row[4], c = 'limegreen')

plt.scatter(2.5, 0.75, color ='b', marker='*', s=150)
plt.scatter(5, 1.75, color ='b', marker='*', s=150)

plt.xlabel('꽃잎 길이')
plt.ylabel('꽃잎 너비')
plt.show()

# %% [markdown]
# (4) KNN으로 학습시켜보자
#
# 1. 모델 만들기
# 2. 모델 학습시키기
# 3. 새로운 데이터 예측해보기

# %%
# 1. 필요한 속성만 추출하기 - 꽃잎 길이, 꽃잎 너비
petal_len_wid = []
species = []

for row in data : 
    petal_len_wid.append([row[3], row[4]])
    species.append(row[5])

# %%
from sklearn.neighbors import KNeighborsClassifier

# 2. KNN 모델 생성하기
model = KNeighborsClassifier(n_neighbors=3)

# %%
# 3. KNN 모델에 학습데이터 넣고 학습시키기 .fit
model.fit(petal_len_wid, species)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
# 4. 새로운 데이터 예측시키기
model.predict([[2.5, 0.75]])
# Out:
# array(['setosa'], dtype='<U10')

# %%
model.predict([[5, 1.75]])
# Out:
# array(['virginica'], dtype='<U10')

# %%
model.predict([[3, 1]])
# Out:
# array(['versicolor'], dtype='<U10')

# %% [markdown]
# ## KNN 2) 지난 연수의 KNN 코드 다시 복습해보기
#
# [KNN 알고리즘 - 라이브러리 없이 직접 프로그래밍하기](https://github.com/Ahnjihye/allinone_AI/blob/master/AIO_AI_day4_(%EC%99%84%EC%84%B1%EB%B3%B8)_kNN_%EB%B6%84%EB%A5%98_%EB%AA%A8%EB%8D%B8.ipynb)

# %% [markdown]
# ## KNN 3) 여러 개의 과일 구분하기
#
# (1) 데이터 업로드 및 숫자 변환

# %%
from google.colab import files
uploaded = files.upload()

import csv 
 
f = open('fruit_data_with_colours.csv')
data = csv.reader(f)
next(data)
data = list(data)
# Out:
#      <input type="file" id="files-675975f6-9103-42a6-8140-0db3d5ba303a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-675975f6-9103-42a6-8140-0db3d5ba303a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fruit_data_with_colours.csv to fruit_data_with_colours.csv

# %%
data[:3]
# Out:
# [['1', 'apple', 'granny_smith', '192', '8.4', '7.3', '0.55'],
#  ['1', 'apple', 'granny_smith', '180', '8', '6.8', '0.59'],
#  ['1', 'apple', 'granny_smith', '176', '7.4', '7.2', '0.6']]

# %%
for row in data : 
    row[0] = int(row[0])
    row[3] = int(row[3])
    row[4] = float(row[4])
    row[5] = float(row[5])
    row[6] = float(row[6])

# %%
data[:3]
# Out:
# [[1, 'apple', 'granny_smith', 192, 8.4, 7.3, 0.55],
#  [1, 'apple', 'granny_smith', 180, 8.0, 6.8, 0.59],
#  [1, 'apple', 'granny_smith', 176, 7.4, 7.2, 0.6]]

# %%
len(data)
# Out:
# 59

# %% [markdown]
# (2) 데이터 시각화
#
# fruit label의 의미
# 1.   apple
# 2.   mandarin
# 3.   orange
# 4.   lemon
#
# <img src='https://ppss.kr/wp-content/uploads/2016/01/pg-1.png' width=400>

# %%
# 가로축이 width(너비), 세로축이 height(길이)인 산점도 + 색상구분 
plt.figure(dpi = 100)
plt.title('과일의 너비와 길이로 과일 구분하기')

for row in data : 
    if row[0] == 1 : # apple
        plt.scatter(row[-3], row[-2], color='r')
    elif row[0] == 2 : # mandarin
        plt.scatter(row[-3], row[-2], color='g')
    elif row[0] == 3 : # orange
        plt.scatter(row[-3], row[-2], color='orange')
    elif row[0] == 4 : # lemon
        plt.scatter(row[-3], row[-2], color='c')

plt.xlabel('너비')
plt.ylabel('길이')
plt.show()

# %%
# 가로축이 mass(무게), 세로축이 color_score(색상)인 산점도 + 색상구분 
plt.figure(dpi = 100)
plt.title('과일의 무게와 색상으로 과일 구분하기')

for row in data : 
    if row[0] == 1 : # apple
        plt.scatter(row[-4], row[-1], color='r')
    elif row[0] == 2 : # mandarin
        plt.scatter(row[-4], row[-1], color='g')
    elif row[0] == 3 : # orange
        plt.scatter(row[-4], row[-1], color='orange')
    elif row[0] == 4 : # lemon
        plt.scatter(row[-4], row[-1], color='c')

plt.xlabel('무게')
plt.ylabel('색상 점수')
plt.show()

# %% [markdown]
# (3) 필요한 속성만 추출하기
#
# *   mass
# *   width
# *   height
# *   color_score

# %%
# 1. 필요한 속성만 추출하기 - 꽃잎 길이, 꽃잎 너비
fruit_feature = []
fruit_name = []

for row in data : 
    fruit_feature.append(row[-4:])
    fruit_name.append(row[1])

# %%
fruit_feature[:2]
# Out:
# [[192, 8.4, 7.3, 0.55], [180, 8.0, 6.8, 0.59]]

# %%
fruit_name[:2]
# Out:
# ['apple', 'apple']

# %% [markdown]
# (4) KNN 학습시키기

# %%
from sklearn.neighbors import KNeighborsClassifier

# KNN 모델 생성하기
model = KNeighborsClassifier(n_neighbors=5)

# %%
# KNN 모델에 학습데이터 넣고 학습시키기 .fit
model.fit(fruit_feature, fruit_name)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
# 새로운 데이터 예측시키기 
model.predict([[350, 9, 8.5, 0.68]])

# %% [markdown]
# (5) 결정 트리로 학습시켜보기

# %%
from sklearn.tree import DecisionTreeClassifier

# 1. 의사결정트리 모델 생성
model_D = DecisionTreeClassifier(max_depth=4)

# 2. 의사결정트리 모델 학습시키기
model_D.fit(fruit_feature, fruit_name)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# 3. 새로운 데이터 예측시켜보기
model_D.predict([[350, 9, 8.5, 0.68]])
# Out:
# array(['orange'], dtype='<U8')

# %% [markdown]
# 의사결정트리 그리는 코드
#
#
# ```
# import graphviz
# from sklearn.tree import export_graphviz
#
# # 의사 결정 트리를 시각화하여 tree.dot 파일로 내보내는 코드
# export_graphviz( 모델이름, out_file ='tree.dot',
#                 feature_names = [학습데이터 속성명],
#                 class_names = [학습 결과로 판단할 분류],
#                 filled = True, rounded = True, impurity = False)
#
# # 위에서 만든 tree.dot을 화면에 보이게 하기
# with open("tree.dot") as f:
#     dot_graph = f.read()
# display(graphviz.Source(dot_graph))
# ```

# %%
import graphviz
from sklearn.tree import export_graphviz
 
# 의사 결정 트리를 시각화하여 tree.dot 파일로 내보내는 코드
export_graphviz(model_D, out_file ='tree.dot',
                feature_names = ['무게','너비','길이','색상'],    
                class_names = ['apple','mandarin','orange','lemon'],
                filled = True, rounded = True, impurity = False)
 
# 위에서 만든 tree.dot을 화면에 보이게 하기
with open("tree.dot") as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))
